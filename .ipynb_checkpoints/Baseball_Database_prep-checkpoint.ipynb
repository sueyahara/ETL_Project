# %%
# Dependencies
# ----------------------------------
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
import pandas as pd

# %%
from sqlalchemy import Column, Integer, String, Float

# %%
# Create Database Connection
# ----------------------------------
# PyMySQL 

import pymysql
pymysql.install_as_MySQLdb()

#mysql_engine = create_engine('mysql://{0}:{1}@{2}:{3}'.format(user, pass, host, port))

engine = create_engine("mysql://group06:gcP5f8UQpkW8w75G@cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com:3306/group06")
conn = engine.connect()

# %%
#print(engine.table_names())

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
Base.metadata.create_all(engine)

# %%
# Use this to clear out the db
# ----------------------------------
Base.metadata.drop_all(engine)

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
Base.metadata.create_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
#engine.execute("CREATE DATABASE group06") #create db
engine.execute("USE group06") # select new db

# %%
#
df1 = pd.read_pickle('merged_s_p.pkl')
df1.head()
# Out:
#            yearID teamID    salary   G  GS    H    R   ER  BB   SO   L  SV  \
# playerID
# boevejo01    1990    ATL  215000.0  33   0   40   23   22  35   35   3   8
# castito02    1990    ATL  100000.0  52   3   93   41   36  20   64   1   1
# claryma01    1990    ATL  125000.0  33  14  128   72   64  39   44  10   0
# glavito02    1990    ATL  285000.0  33  33  232  111  102  78  129  12   0
# greento01    1990    ATL  100000.0   5   2   14   11   11   9    4   0   0
#
#             W  BAOpp   ERA
# playerID
# boevejo01   1  0.252  4.68
# castito02   5  0.302  4.23
# claryma01   1  0.308  5.67
# glavito02  10  0.281  4.28
# greento01   1  0.286  8.03

# %%
df1.reset_index()
# Out:
#         playerID  yearID teamID     salary   G  GS    H    R   ER  BB   SO  \
# 0      boevejo01    1990    ATL   215000.0  33   0   40   23   22  35   35
# 1      castito02    1990    ATL   100000.0  52   3   93   41   36  20   64
# 2      claryma01    1990    ATL   125000.0  33  14  128   72   64  39   44
# 3      glavito02    1990    ATL   285000.0  33  33  232  111  102  78  129
# 4      greento01    1990    ATL   100000.0   5   2   14   11   11   9    4
# 5      henrydw01    1990    ATL   120000.0  34   0   41   26   24  25   34
# 6      leibrch01    1990    ATL  1000000.0  24  24  164   72   57  35   76
# 7      lillide01    1990    ATL   135000.0  12  11   75   45   43  19   34
# 8      lueckri01    1990    ATL   114000.0  36   0   73   36   34  30   35
# 9      merckke01    1990    ATL   102000.0  36   0   43   22   17  24   39
# 10     smithpe02    1990    ATL   190000.0  13  13   77   45   41  24   56
# ...

# %%
df1.to_sql('salary_pitching',
           con = engine, 
           index = True,
           if_exists = 'replace'
)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
# ...

# %%
print(engine.table_names())

# %%
pd.read_sql("salary_pitching", engine)
# Out:
# Empty DataFrame
# Columns: [playerID, yearID, teamID, salary, G, GS, H, R, ER, BB, SO, L, SV, W, BAOpp, ERA]
# Index: []

# %%
pd.read_sql("merged_s_p.pkl", engine)
# Out:
# Empty DataFrame
# Columns: [playerID, yearID, teamID, salary, G, GS, H, R, ER, BB, SO, L, SV, W, BAOpp, ERA]
# Index: []

# %%
df1.to_sql('salary_pitching',
           con = engine, 
           index = True,
           if_exists = 'append'
)

# %%
pd.read_sql("salary_pitching", engine)
# Out:
#         playerID  yearID teamID     salary   G  GS    H    R   ER  BB   SO  \
# 0      boevejo01    1990    ATL   215000.0  33   0   40   23   22  35   35
# 1      castito02    1990    ATL   100000.0  52   3   93   41   36  20   64
# 2      claryma01    1990    ATL   125000.0  33  14  128   72   64  39   44
# 3      glavito02    1990    ATL   285000.0  33  33  232  111  102  78  129
# 4      greento01    1990    ATL   100000.0   5   2   14   11   11   9    4
# 5      henrydw01    1990    ATL   120000.0  34   0   41   26   24  25   34
# 6      leibrch01    1990    ATL  1000000.0  24  24  164   72   57  35   76
# 7      lillide01    1990    ATL   135000.0  12  11   75   45   43  19   34
# 8      lueckri01    1990    ATL   114000.0  36   0   73   36   34  30   35
# 9      merckke01    1990    ATL   102000.0  36   0   43   22   17  24   39
# 10     smithpe02    1990    ATL   190000.0  13  13   77   45   41  24   56
# ...

# %%
merged_s_p.pkl.drop(engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-b2622df6ee93> in <module>()
# ----> 1 merged_s_p.pkl.drop(engine)
#
# NameError: name 'merged_s_p' is not defined

# %%
print(engine.table_names())
# Out:
# ['merged_s_p.pkl', 'salary_pitching']

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['merged_s_p.pkl', 'salary_pitching']
