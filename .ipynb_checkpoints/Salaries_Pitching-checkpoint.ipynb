# %%
import pandas as pd
import numpy as np

# %%
salary = pd.read_csv("Resources/Salaries.csv")
salary.head(10)
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000
# 5    1985    ATL   NL  chambch01  800000
# 6    1985    ATL   NL  dedmoje01  150000
# 7    1985    ATL   NL  forstte01  483333
# 8    1985    ATL   NL  garbege01  772000
# 9    1985    ATL   NL  harpete01  250000

# %%
salary_year = salary[salary['yearID'] >= 1990]
salary_year.head()
# Out:
#       yearID teamID lgID   playerID  salary
# 3289    1990    ATL   NL   bellmi01  100000
# 3290    1990    ATL   NL  blausje01  180000
# 3291    1990    ATL   NL  boevejo01  215000
# 3292    1990    ATL   NL  castito02  100000
# 3293    1990    ATL   NL  claryma01  125000

# %%
salary_year_cleaned = salary_year.drop(columns=['lgID'])
salary_year_cleaned.head()
# Out:
#       yearID teamID   playerID  salary
# 3289    1990    ATL   bellmi01  100000
# 3290    1990    ATL  blausje01  180000
# 3291    1990    ATL  boevejo01  215000
# 3292    1990    ATL  castito02  100000
# 3293    1990    ATL  claryma01  125000

# %%
salary_index = salary_year_cleaned.set_index(['playerID', 'yearID'])
salary_index.head()
# Out:
#                  teamID  salary
# playerID  yearID
# bellmi01  1990      ATL  100000
# blausje01 1990      ATL  180000
# boevejo01 1990      ATL  215000
# castito02 1990      ATL  100000
# claryma01 1990      ATL  125000

# %%
len(salary_index.index)
# Out:
# 23139

# %%
salary_index.dtypes
# Out:
# teamID    object
# salary     int64
# dtype: object

# %%
salary_index.dropna()
# Out:
#                  teamID    salary
# playerID  yearID
# bellmi01  1990      ATL    100000
# blausje01 1990      ATL    180000
# boevejo01 1990      ATL    215000
# castito02 1990      ATL    100000
# claryma01 1990      ATL    125000
# davisjo02 1990      ATL    800000
# esaskni01 1990      ATL   1350000
# gantro01  1990      ATL    125000
# glavito02 1990      ATL    285000
# greento01 1990      ATL    100000
# greggto01 1990      ATL    155000
# henrydw01 1990      ATL    120000
# huntebr01 1990      ATL    100000
# infanal01 1990      ATL    114000
# leibrch01 1990      ATL   1000000
# lillide01 1990      ATL    135000
# lueckri01 1990      ATL    114000
# mcdowod01 1990      ATL    690000
# merckke01 1990      ATL    102000
# mitchke02 1990      ATL    100000
# murphda05 1990      ATL   2000000
# preslji01 1990      ATL    640000
# rosarvi01 1990      ATL    100000
# smithlo01 1990      ATL   1458334
# smithpe02 1990      ATL    190000
# smoltjo01 1990      ATL    210000
# ...

# %%
pitching = pd.read_csv("Resources/pitching.csv")
pitching.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...   IBB  WP  \
# 0  bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...   NaN   7
# 1  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...   NaN   7
# 2  fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...   NaN   2
# 3  fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...   NaN  20
# 4  fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...   NaN   0
#
#    HBP  BK     BFP  GF    R  SH  SF  GIDP
# 0  NaN   0   146.0   0   42 NaN NaN   NaN
# 1  NaN   0  1291.0   0  292 NaN NaN   NaN
# 2  NaN   0    14.0   0    9 NaN NaN   NaN
# 3  NaN   0  1080.0   1  257 NaN NaN   NaN
# 4  NaN   0    57.0   0   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
pitching_year = pitching[pitching['yearID'] >= 1990]
pitching_year.head()
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...   IBB  \
# 27294   aasedo01    1990      1    LAN   NL   3   1  32   0   0  ...   4.0
# 27295  abbotji01    1990      1    CAL   AL  10  14  33  33   4  ...   6.0
# 27296  abbotpa01    1990      1    MIN   AL   0   5   7   7   0  ...   0.0
# 27297  ackerji01    1990      1    TOR   AL   4   4  59   0   0  ...   5.0
# 27298  adkinst01    1990      1    NYA   AL   1   2   5   5   0  ...   0.0
#
#        WP  HBP  BK    BFP  GF    R   SH   SF  GIDP
# 27294   3  0.0   0  163.0  13   24  2.0  0.0   2.0
# 27295   4  5.0   3  925.0   0  116  9.0  6.0  27.0
# 27296   1  1.0   0  162.0   0   24  1.0  1.0   4.0
# 27297   4  3.0   1  403.0  19   49  3.0  1.0   6.0
# 27298   2  0.0   0  115.0   0   18  1.0  1.0   3.0
#
# [5 rows x 30 columns]

# %%
#pitching_index = pitching_year.set_index(['playerID', 'yearID'])
#pitching_index.head()

# %%
#len(pitching_index.index)

# %%
pitching_year.columns
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP'],
#       dtype='object')

# %%
pitching_newdf = pitching_year[['playerID', 'yearID', 'teamID', 'G', 'GS', 'H', 'R', 'ER', 'BB', 'SO', 'L','SV', 'W', 'BAOpp', 'ERA']]
pitching_newdf.head()
# Out:
#         playerID  yearID teamID   G  GS    H    R   ER  BB   SO   L  SV   W  \
# 27294   aasedo01    1990    LAN  32   0   33   24   21  19   24   1   3   3
# 27295  abbotji01    1990    CAL  33  33  246  116  106  72  105  14   0  10
# 27296  abbotpa01    1990    MIN   7   7   37   24   23  28   25   5   0   0
# 27297  ackerji01    1990    TOR  59   0  103   49   39  30   54   4   1   4
# 27298  adkinst01    1990    NYA   5   5   19   18   17  29   14   2   0   1
#
#        BAOpp   ERA
# 27294  0.232  4.97
# 27295  0.295  4.51
# 27296  0.282  5.97
# 27297  0.281  3.83
# 27298  0.226  6.38

# %%
pitching_newdf.dtypes
# Out:
# playerID     object
# yearID        int64
# teamID       object
# G             int64
# GS            int64
# H             int64
# R             int64
# ER            int64
# BB            int64
# SO            int64
# L             int64
# SV            int64
# W             int64
# BAOpp       float64
# ERA         float64
# dtype: object

# %%
pitching_cleaned = pitching_newdf.dropna()
pitching_cleaned
# Out:
#         playerID  yearID teamID   G  GS    H    R   ER  BB   SO   L  SV   W  \
# 27294   aasedo01    1990    LAN  32   0   33   24   21  19   24   1   3   3
# 27295  abbotji01    1990    CAL  33  33  246  116  106  72  105  14   0  10
# 27296  abbotpa01    1990    MIN   7   7   37   24   23  28   25   5   0   0
# 27297  ackerji01    1990    TOR  59   0  103   49   39  30   54   4   1   4
# 27298  adkinst01    1990    NYA   5   5   19   18   17  29   14   2   0   1
# 27299  agostju01    1990    HOU  82   0   91   46   44  39   50   8   4   9
# 27300  aguilri01    1990    MIN  56   0   55   27   20  19   61   3  32   5
# 27301  akerfda01    1990    PHI  71   0   65   45   39  54   42   2   3   5
# 27302  aldresc01    1990    DET   4   3   13    6    6  10    7   2   0   1
# 27303  aldrija01    1990    BAL   7   0   17   13   11   7    5   2   1   1
# 27304  alexage01    1990    TEX   3   2   14    6    6   5    8   0   0   0
# ...

# %%
#merged_s_p = pd.merge(salary_year_cleaned, pitching_cleaned, on = 'playerID')
#merged_s_p.set_index('playerID', inplace = True)
#merged_s_p

# %%
salary_pitching_index = salary_index.reset_index().merge(pitching_cleaned, how="right").set_index('playerID')
salary_pitching_index
# Out:
#            yearID teamID     salary   G  GS    H    R   ER  BB   SO   L  SV  \
# playerID
# boevejo01    1990    ATL   215000.0  33   0   40   23   22  35   35   3   8
# castito02    1990    ATL   100000.0  52   3   93   41   36  20   64   1   1
# claryma01    1990    ATL   125000.0  33  14  128   72   64  39   44  10   0
# glavito02    1990    ATL   285000.0  33  33  232  111  102  78  129  12   0
# greento01    1990    ATL   100000.0   5   2   14   11   11   9    4   0   0
# henrydw01    1990    ATL   120000.0  34   0   41   26   24  25   34   2   0
# leibrch01    1990    ATL  1000000.0  24  24  164   72   57  35   76  11   0
# lillide01    1990    ATL   135000.0  12  11   75   45   43  19   34   8   0
# lueckri01    1990    ATL   114000.0  36   0   73   36   34  30   35   4   1
# merckke01    1990    ATL   102000.0  36   0   43   22   17  24   39   7   7
# smithpe02    1990    ATL   190000.0  13  13   77   45   41  24   56   6   0
# ...

# %%
salary_pitching_index.to_pickle('merged_s_p.pkl')
